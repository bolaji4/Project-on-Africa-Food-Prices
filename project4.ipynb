# %% [markdown]
# ### PROJECT ON AFRICA FOOD PRICE

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats

# %matplotlib inline

print('installation is ready')
# Out:
# installation is ready

# %%
url = ('./datasets/africa_food_prices.csv')

# %%
df = pd.read_csv(url)

# %%
df.head(3)
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# 0           5       KG      4  2015   90.0                 NaN
# 1           5       KG      5  2015   96.0                 NaN
# 2           5       KG      6  2015   96.0                 NaN

# %%
## datas that exist in the columns
df.shape
# Out:
# (956779, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   country             956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   market              956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   produce             956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  currency            956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_unit_id          956779 non-null  int64
#  14  quantity            956779 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
df[['country_id', 'country', 'market_id', 'produce_id']]
# Out:
#         country_id   country  market_id  produce_id
# 0              4.0   Algeria       1794          52
# 1              4.0   Algeria       1794          52
# 2              4.0   Algeria       1794          52
# 3              4.0   Algeria       1794          52
# 4              4.0   Algeria       1794          52
# ...            ...       ...        ...         ...
# 956774       271.0  Zimbabwe       5594         432
# 956775       271.0  Zimbabwe       5594         539
# 956776       271.0  Zimbabwe       5594         540
# 956777       271.0  Zimbabwe       5594         541
# 956778       271.0  Zimbabwe       5594         887
#
# [956779 rows x 4 columns]

# %%
df.dropna(axis='columns')
# Out:
#         Unnamed: 0  country_id   country  state_id  market_id      market  \
# 0            15427         4.0   Algeria       344       1794     Algiers
# 1            15428         4.0   Algeria       344       1794     Algiers
# 2            15429         4.0   Algeria       344       1794     Algiers
# 3            15430         4.0   Algeria       344       1794     Algiers
# 4            15431         4.0   Algeria       344       1794     Algiers
# ...            ...         ...       ...       ...        ...         ...
# 956774     2050633       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956775     2050634       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956776     2050635       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956777     2050636       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956778     2050637       271.0  Zimbabwe      3444       5594  Mbilashaba
#
#         produce_id                  produce  currency_id currency  pt_id  \
# ...

# %%
df[['country_id', 'country', 'market_id', 'produce_id']].describe()
# Out:
#           country_id      market_id     produce_id
# count  956779.000000  956779.000000  956779.000000
# mean     1961.192782    1392.594222     186.141214
# std     10404.034922    1027.751212     165.401303
# min         4.000000     101.000000      50.000000
# 25%        90.000000     528.000000      67.000000
# 50%       155.000000    1078.000000     105.000000
# 75%       205.000000    2281.000000     262.000000
# max     70001.000000    6081.000000     887.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
df.dropna(axis = 'columns')
# Out:
#         Unnamed: 0  country_id   country  state_id  market_id      market  \
# 0            15427         4.0   Algeria       344       1794     Algiers
# 1            15428         4.0   Algeria       344       1794     Algiers
# 2            15429         4.0   Algeria       344       1794     Algiers
# 3            15430         4.0   Algeria       344       1794     Algiers
# 4            15431         4.0   Algeria       344       1794     Algiers
# ...            ...         ...       ...       ...        ...         ...
# 956774     2050633       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956775     2050634       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956776     2050635       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956777     2050636       271.0  Zimbabwe      3444       5594  Mbilashaba
# 956778     2050637       271.0  Zimbabwe      3444       5594  Mbilashaba
#
#         produce_id                  produce  currency_id currency  pt_id  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
all_cols = ['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
       'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
       'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
       'mp_commoditysource'],

      
cols_to_drop = ['Unnamed: 0','country_id','state_id',
                'currency_id','pt_id',
                'mp_commoditysource']

# %%
df = df.drop(columns=cols_to_drop)

# %%
df.shape
# Out:
# (956779, 13)

# %%
df.columns
# Out:
# Index(['country', 'state', 'market_id', 'market', 'produce_id', 'produce',
#        'currency', 'market_type', 'um_unit_id', 'quantity', 'month', 'year',
#        'price'],
#       dtype='object')

# %%
new_names = {'country': 'country',
            'state': 'state',
            'market_id': 'mkt_id',
            'market': 'mkt_name',
            'produce_id': 'pd_id',
            'market_type': 'mkt_type',
            'um_unit_id': 'measurement_id',
            'quantity': 'weight',
             'produce': 'product',
            'month':'month_recorded',
            'year':'year_recorded',
            'price':'price_paid'}

# %%
df = df.rename(columns=new_names)

# %%
df.head(3)
# Out:
#    country  state  mkt_id mkt_name  pd_id        product currency mkt_type  \
# 0  Algeria  Alger    1794  Algiers     52  Rice - Retail      DZD   Retail
# 1  Algeria  Alger    1794  Algiers     52  Rice - Retail      DZD   Retail
# 2  Algeria  Alger    1794  Algiers     52  Rice - Retail      DZD   Retail
#
#    measurement_id weight  month_recorded  year_recorded  price_paid
# 0               5     KG               4           2015        90.0
# 1               5     KG               5           2015        96.0
# 2               5     KG               6           2015        96.0

# %%
all_cols = ['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
       'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
       'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
       'mp_commoditysource'], 
numericCols = ['mkt_id', 'pd_id','measurement_id', 'price_paid',]
cateCols = []
prodCols = ['country', 'mkt_name', 'product',
       'currency']
region = ['country', 'state','product']

# %%
df[region]
# Out:
#          country     state                  product
# 0        Algeria     Alger            Rice - Retail
# 1        Algeria     Alger            Rice - Retail
# 2        Algeria     Alger            Rice - Retail
# 3        Algeria     Alger            Rice - Retail
# 4        Algeria     Alger            Rice - Retail
# ...          ...       ...                      ...
# 956774  Zimbabwe  Midlands   Beans (sugar) - Retail
# 956775  Zimbabwe  Midlands      Toothpaste - Retail
# 956776  Zimbabwe  Midlands    Laundry soap - Retail
# 956777  Zimbabwe  Midlands   Handwash soap - Retail
# 956778  Zimbabwe  Midlands  Fish (kapenta) - Retail
#
# [956779 rows x 3 columns]

# %% [markdown]
# ## TABLE QUERY

# %%
df[region].country.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Burundi', 'Cameroon', 'Cape Verde',
#        'Central African Republic', 'Chad', 'Congo', 'Djibouti', 'Egypt',
#        'Eritrea', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea',
#        'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mozambique',
#        'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Swaziland',
#        'Togo', 'Uganda', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
len(df[region].state.unique())
# Out:
# 312

# %%
len(df[region].country.unique())
# Out:
# 42

# %%
market=df.groupby('mkt_type')
market.first()
# Out:
#               country       state  mkt_id             mkt_name  pd_id  \
# mkt_type
# Producer   Madagascar  Atsinanana     750  Atsinanana (Region)    203
# Retail        Algeria       Alger    1794              Algiers     52
# Wholesale       Benin     Alibori    1044     Malanville (CBM)     51
#
#                            product currency  measurement_id weight  \
# mkt_type
# Producer   Rice (paddy) - Producer      MGA               5     KG
# Retail               Rice - Retail      DZD               5     KG
# Wholesale        Maize - Wholesale      XOF               5     KG
#
#            month_recorded  year_recorded  price_paid
# mkt_type
# Producer                4           2011       950.0
# Retail                  4           2015        90.0
# Wholesale               1           2002       145.0

# %%
#df['mkt_type'].unique()

# %%
mkt_type = df[df['mkt_type'] == 'Retail']

# %%
mkt_type
# Out:
#          country     state  mkt_id    mkt_name  pd_id  \
# 0        Algeria     Alger    1794     Algiers     52
# 1        Algeria     Alger    1794     Algiers     52
# 2        Algeria     Alger    1794     Algiers     52
# 3        Algeria     Alger    1794     Algiers     52
# 4        Algeria     Alger    1794     Algiers     52
# ...          ...       ...     ...         ...    ...
# 956774  Zimbabwe  Midlands    5594  Mbilashaba    432
# 956775  Zimbabwe  Midlands    5594  Mbilashaba    539
# 956776  Zimbabwe  Midlands    5594  Mbilashaba    540
# 956777  Zimbabwe  Midlands    5594  Mbilashaba    541
# 956778  Zimbabwe  Midlands    5594  Mbilashaba    887
#
#                         product currency mkt_type  measurement_id  weight  \
# 0                 Rice - Retail      DZD   Retail               5      KG
# 1                 Rice - Retail      DZD   Retail               5      KG
# 2                 Rice - Retail      DZD   Retail               5      KG
# ...

# %%
mkt_type = df[df['mkt_type'] == 'Wholesale']

# %%
mkt_type
# Out:
#        country    state  mkt_id          mkt_name  pd_id  \
# 3065     Benin  Alibori    1044  Malanville (CBM)     51
# 3066     Benin  Alibori    1044  Malanville (CBM)     51
# 3067     Benin  Alibori    1044  Malanville (CBM)     51
# 3068     Benin  Alibori    1044  Malanville (CBM)     51
# 3069     Benin  Alibori    1044  Malanville (CBM)     51
# ...        ...      ...     ...               ...    ...
# 902012  Uganda     Lira     263              Lira    147
# 902013  Uganda     Lira     263              Lira    147
# 902014  Uganda     Lira     263              Lira    147
# 902015  Uganda     Lira     263              Lira    147
# 902016  Uganda     Lira     263              Lira    147
#
#                       product currency   mkt_type  measurement_id weight  \
# 3065        Maize - Wholesale      XOF  Wholesale               5     KG
# 3066        Maize - Wholesale      XOF  Wholesale               5     KG
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(df[region].country)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\user\Data_Analysis\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#mkt_type.to_csv('./datasets/africa_food_prices.csv', index=False) # to save my clean data on csv

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[numericCols].price_paid.loc[:1200])
# Out:
# <AxesSubplot:>

# %%
mkt_type = pd.pivot_table(df, index=["country","mkt_name","year_recorded",],values=["price_paid"], aggfunc='mean')

# %%
mkt_type
# Out:
#                                          price_paid
# country  mkt_name         year_recorded
# Algeria  Algiers          2015           144.455615
#                           2016           139.979592
#          Auserd           2016           176.449275
#          Boujdour         2016           193.011364
#          Dakhla           2015           168.468137
# ...                                             ...
# Zimbabwe Victoria Falls   2021           227.300030
#          Zezani           2020            98.899650
#          Zvishavane Urban 2019             1.748000
#                           2020           206.956577
#                           2021           227.907827
#
# [13768 rows x 1 columns]

# %%
mkt_type = pd.pivot_table(df, index=["country","mkt_name","year_recorded",],values=["price_paid"], aggfunc='sum')

# %%
mkt_type
# Out:
#                                          price_paid
# country  mkt_name         year_recorded
# Algeria  Algiers          2015           27013.2000
#                           2016           20577.0000
#          Auserd           2016           24350.0000
#          Boujdour         2016           16985.0000
#          Dakhla           2015           34367.5000
# ...                                             ...
# Zimbabwe Victoria Falls   2021            9092.0012
#          Zezani           2020            1582.3944
#          Zvishavane Urban 2019               8.7400
#                           2020            6415.6539
#                           2021            2506.9861
#
# [13768 rows x 1 columns]

# %%
mkt_type.query("country == ['Nigeria']")
# Out:
#                                   price_paid
# country mkt_name year_recorded
# Nigeria Aba      2014           2.697728e+04
#                  2015           5.026969e+04
#                  2016           5.242719e+04
#                  2017           2.046543e+06
#                  2021           1.061320e+06
# ...                                      ...
#         Yusufari 2017           1.182850e+05
#                  2018           1.131000e+05
#                  2019           8.440500e+04
#                  2020           7.451500e+04
#                  2021           3.972800e+04
#
# [318 rows x 1 columns]

# %%
df2 = mkt_type.reset_index()
df2.head(3)
# Out:
#    country mkt_name  year_recorded  price_paid
# 0  Algeria  Algiers           2015     27013.2
# 1  Algeria  Algiers           2016     20577.0
# 2  Algeria   Auserd           2016     24350.0

# %%
plt.figure(figsize=(18,50))
df2[['country','mkt_name','year_recorded','price_paid']].plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.month_recorded.value_counts()
# Out:
# 5     85030
# 6     83583
# 4     82974
# 7     82862
# 3     82299
# 2     81356
# 1     80400
# 8     76861
# 9     76521
# 10    75082
# 11    75059
# 12    74752
# Name: month_recorded, dtype: int64

# %%
df.year_recorded.value_counts()
# Out:
# 2020    156199
# 2019     99606
# 2021     91234
# 2018     81720
# 2015     71853
# 2017     66916
# 2014     65238
# 2013     61206
# 2016     52378
# 2012     48916
# 2011     36103
# 2010     27993
# 2009     24725
# 2008     20968
# 2007     15266
# 2006      9421
# 2005      5832
# 2004      4750
# 2003      4356
# 2002      2153
# 2001      1770
# 2000      1319
# 1998      1224
# 1999      1182
# 1997      1065
# 1996      1045
# 1995       924
# 1994       843
# 1993       152
# 1992       148
# 1990       140
# 1991       134
# Name: year_recorded, dtype: int64

# %%
df.mkt_name.value_counts()
# Out:
# Serrekunda        4130
# Banjul            4127
# Brikama           4111
# Basse Santa su    4028
# Farafenni         3937
#                   ...
# Bongo                2
# Socogim              2
# Faya                 2
# Vigwagwa             1
# Ali Addeh            1
# Name: mkt_name, Length: 1696, dtype: int64

# %%
df.state.value_counts()
# Out:
# North/Amajyaruguru     34770
# South/Amajyepfo        31610
# East/Iburasirazuba     30805
# West/Iburengerazuba    30032
# Yobe                   15671
#                        ...
# Tiris-Zemmour             29
# Toliara                   24
# Kabale                    24
# Lunda Norte               24
# Semenawi Keih Bahri       18
# Name: state, Length: 311, dtype: int64

# %%
mkt_type
# Out:
#                                          price_paid
# country  mkt_name         year_recorded
# Algeria  Algiers          2015           27013.2000
#                           2016           20577.0000
#          Auserd           2016           24350.0000
#          Boujdour         2016           16985.0000
#          Dakhla           2015           34367.5000
# ...                                             ...
# Zimbabwe Victoria Falls   2021            9092.0012
#          Zezani           2020            1582.3944
#          Zvishavane Urban 2019               8.7400
#                           2020            6415.6539
#                           2021            2506.9861
#
# [13768 rows x 1 columns]

# %%
mkt_type
# Out:
#                                          price_paid
# country  mkt_name         year_recorded
# Algeria  Algiers          2015           27013.2000
#                           2016           20577.0000
#          Auserd           2016           24350.0000
#          Boujdour         2016           16985.0000
#          Dakhla           2015           34367.5000
# ...                                             ...
# Zimbabwe Victoria Falls   2021            9092.0012
#          Zezani           2020            1582.3944
#          Zvishavane Urban 2019               8.7400
#                           2020            6415.6539
#                           2021            2506.9861
#
# [13768 rows x 1 columns]
